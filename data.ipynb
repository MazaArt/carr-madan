# %%
import yfinance as yf
import pandas as pd
import scipy

# %%
stocks = {
    "Apple" : "AAPL",
    "Microsoft" : "MSFT",
    "Nvidia" : "NVDA",
    "Palantir" : "PLTR",
    "Google" : "GOOG"
}

# %%
tkr = "^SPX"
stock_data = yf.Ticker(tkr)
print(stock_data.option_chain(stock_data.options[0])._fields)
# fields of option - calls, puts, underlying
# Out:
# ('calls', 'puts', 'underlying')

# %%
# properties of puts and calls
props = ['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
       'change', 'percentChange', 'volume', 'openInterest',
       'impliedVolatility', 'inTheMoney', 'contractSize', 'currency']

print(stock_data.option_chain(stock_data.options[0]).calls.columns)

print(stock_data.option_chain(stock_data.options[0]).puts.columns)

underlying_props = list(stock_data.option_chain(stock_data.options[0]).underlying.keys())

# print underlying properties
for i in range(len(underlying_props)):
    print(f"{underlying_props[i]}", end = ", ")
    if i > 0 and i % 5 == 0:
       print()
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency'],
#       dtype='object')
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency'],
#       dtype='object')
# language, region, quoteType, typeDisp, quoteSourceName, triggerable,
# customPriceAlertConfidence, regularMarketChange, regularMarketDayHigh, regularMarketDayRange, regularMarketDayLow,
# regularMarketVolume, regularMarketPreviousClose, bid, ask, bidSize,
# askSize, fullExchangeName, regularMarketOpen, averageDailyVolume3Month, averageDailyVolume10Day,
# fiftyTwoWeekLowChange, fiftyTwoWeekLowChangePercent, fiftyTwoWeekRange, fiftyTwoWeekHighChange, fiftyTwoWeekHighChangePercent,
# fiftyTwoWeekLow, fiftyTwoWeekHigh, fiftyTwoWeekChangePercent, currency, fiftyDayAverage,
# fiftyDayAverageChange, fiftyDayAverageChangePercent, twoHundredDayAverage, twoHundredDayAverageChange, twoHundredDayAverageChangePercent,
# sourceInterval, exchangeDataDelayedBy, corporateActions, regularMarketTime, underlyingSymbol,
# exchange, messageBoardId, exchangeTimezoneName, exchangeTimezoneShortName, gmtOffSetMilliseconds,
# market, esgPopulated, regularMarketChangePercent, regularMarketPrice, marketState,
# shortName, hasPrePostMarketData, firstTradeDateMilliseconds, priceHint, tradeable,
# cryptoTradeable, longName, symbol,

# %%
exp_dat_map = dict() # map date to idx of stock_data.options 
print(stock_data.options)
for idx, exp in enumerate(stock_data.options): # this consists of a tuple of dates that is only iterable
    exp_dat_map[exp] = idx

# Note: we can only pull future pricing data 
future_date = "2026-04-30"
exp_arg = exp_dat_map[future_date]

# why are there more put options than call options 
print(stock_data.option_chain(stock_data.options[exp_arg]).calls.iloc[180:195])
print(stock_data.option_chain(stock_data.options[exp_arg]).puts)
# Out:
# ('2026-04-13', '2026-04-14', '2026-04-15', '2026-04-16', '2026-04-17', '2026-04-20', '2026-04-21', '2026-04-22', '2026-04-23', '2026-04-24', '2026-04-27', '2026-04-28', '2026-04-29', '2026-04-30', '2026-05-01', '2026-05-04', '2026-05-05', '2026-05-06', '2026-05-07', '2026-05-08', '2026-05-11', '2026-05-12', '2026-05-13', '2026-05-14', '2026-05-15', '2026-05-18', '2026-05-19', '2026-05-22', '2026-05-29', '2026-06-05', '2026-06-18', '2026-06-30', '2026-07-17', '2026-07-31', '2026-08-21', '2026-08-31', '2026-09-18', '2026-09-30', '2026-10-16', '2026-11-20', '2026-12-18', '2026-12-31', '2027-01-15', '2027-02-19', '2027-03-19', '2027-03-31', '2027-04-16', '2027-06-17', '2027-12-17', '2028-12-15', '2029-12-21', '2030-12-20', '2031-12-19')
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 180  SPXW260430C06770000 2026-04-13 13:39:25+00:00  6770.0     123.09  133.0
# 181  SPXW260430C06775000 2026-04-10 17:31:11+00:00  6775.0     134.14  129.6
# 182  SPXW260430C06780000 2026-04-10 18:20:57+00:00  6780.0     134.10  126.2
# 183  SPXW260430C06785000 2026-04-10 19:33:52+00:00  6785.0     127.80  125.6
# 184  SPXW260430C06790000 2026-04-13 13:53:07+00:00  6790.0     113.40  122.2
# 185  SPXW260430C06795000 2026-04-13 13:45:30+00:00  6795.0     104.20  115.4
# 186  SPXW260430C06800000 2026-04-13 13:53:07+00:00  6800.0     107.00  112.1
# 187  SPXW260430C06805000 2026-04-10 19:55:47+00:00  6805.0     110.38  110.2
# 188  SPXW260430C06810000 2026-04-10 19:58:56+00:00  6810.0     109.52  106.2
# 189  SPXW260430C06815000 2026-04-13 13:48:50+00:00  6815.0      97.45  103.5
# 190  SPXW260430C06820000 2026-04-13 13:48:50+00:00  6820.0      94.30  102.8
# 191  SPXW260430C06825000 2026-04-13 13:31:54+00:00  6825.0      89.15   96.8
# 192  SPXW260430C06830000 2026-04-10 19:58:56+00:00  6830.0      97.04   93.8
# 193  SPXW260430C06835000 2026-04-10 19:29:29+00:00  6835.0      82.30   91.0
# 194  SPXW260430C06840000 2026-04-10 17:20:49+00:00  6840.0      93.55   88.0
#
#        ask     change  percentChange  volume  openInterest  impliedVolatility  \
# 180  133.6 -14.660004     -10.642471     8.0            90           0.182572
# 181  130.2   0.000000       0.000000   131.0           538           0.181504
# 182  126.8   0.000000       0.000000    16.0           210           0.180382
# 183  126.4   0.000000       0.000000     7.0           117           0.184214
# 184  122.8 -13.059998     -10.327374    21.0           191           0.182637
# 185  116.0 -17.330002     -14.259855    18.0           123           0.175683
# 186  112.8  -6.580002      -5.793275   154.0          5534           0.174668
# 187  111.0   0.000000       0.000000    32.0           314           0.175915
# 188  107.0   0.000000       0.000000    21.0           424           0.173455
# 189  104.1  -7.280006      -6.951213     1.0            84           0.172753
# 190  105.2  -8.070000      -7.883169     1.0           321           0.178616
# 191   97.4 -11.049995     -11.027940    20.0           578           0.169675
# 192   94.4   0.000000       0.000000    16.0           511           0.168618
# 193   91.6 -14.169998     -14.688501     1.0           403           0.167828
# 194   88.8   0.000000       0.000000     6.0           561           0.166970
#
#      inTheMoney contractSize currency
# 180        True      REGULAR      USD
# 181        True      REGULAR      USD
# 182        True      REGULAR      USD
# 183        True      REGULAR      USD
# 184        True      REGULAR      USD
# 185        True      REGULAR      USD
# 186        True      REGULAR      USD
# 187        True      REGULAR      USD
# 188        True      REGULAR      USD
# 189       False      REGULAR      USD
# 190       False      REGULAR      USD
# 191       False      REGULAR      USD
# 192       False      REGULAR      USD
# 193       False      REGULAR      USD
# 194       False      REGULAR      USD
#           contractSymbol             lastTradeDate  strike  lastPrice  \
# 0    SPXW260430P02600000 2026-04-07 17:00:06+00:00  2600.0       0.20
# 1    SPXW260430P02800000 2026-04-07 15:27:07+00:00  2800.0       0.20
# 2    SPXW260430P03000000 2026-04-13 13:47:34+00:00  3000.0       0.10
# 3    SPXW260430P03200000 2026-04-08 17:50:23+00:00  3200.0       0.15
# 4    SPXW260430P03400000 2026-04-13 10:03:37+00:00  3400.0       0.20
# ..                   ...                       ...     ...        ...
# 382  SPXW260430P07990000 2026-03-06 19:46:50+00:00  7990.0    1194.55
# 383  SPXW260430P08000000 2026-04-01 17:23:50+00:00  8000.0    1371.35
# 384  SPXW260430P08100000 2026-03-23 16:12:25+00:00  8100.0    1473.58
# 385  SPXW260430P08600000 2026-04-07 14:43:37+00:00  8600.0    2018.71
# 386  SPXW260430P08800000 2026-04-02 16:51:17+00:00  8800.0    2213.76
#
#          bid      ask  change  percentChange  volume  openInterest  \
# 0       0.00     0.15    0.00       0.000000   172.0          1117
# 1       0.00     0.15    0.00       0.000000    31.0          5697
# 2       0.05     0.10   -0.10     -50.000000  2531.0           588
# 3       0.00     0.20    0.00       0.000000    35.0           274
# 4       0.05     0.20    0.09      81.818184   150.0          5187
# ..       ...      ...     ...            ...     ...           ...
# 382  1380.10  1404.10    0.00       0.000000     2.0             0
# 383  1166.70  1186.20    0.00       0.000000    39.0            54
# 384  1261.90  1280.70    0.00       0.000000     NaN             1
# 385  1765.00  1782.10    0.00       0.000000     1.0             2
# 386  1963.50  1981.80    0.00       0.000000     1.0            18
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             1.250004       False      REGULAR      USD
# 1             1.156254       False      REGULAR      USD
# 2             1.070317       False      REGULAR      USD
# 3             1.009771       False      REGULAR      USD
# 4             0.947266       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 382           0.979756        True      REGULAR      USD
# 383           0.284126        True      REGULAR      USD
# 384           0.000010        True      REGULAR      USD
# 385           0.000010        True      REGULAR      USD
# 386           0.000010        True      REGULAR      USD
#
# [387 rows x 14 columns]

# %%
# ex tkr: 'NVDA'
# ex date: '2026-03-26' (YYYY-MM-DD)
def get_call_data(tkr, date):
    stock_data = yf.Ticker(tkr)
    return stock_data.option_chain(stock_data.options[exp_dat_map[date]]).calls

def get_put_data(tkr, date):
    stock_data = yf.Ticker(tkr)
    return stock_data.option_chain(stock_data.options[exp_dat_map[date]]).puts

# print(get_call_data('NVDA', '2026-04-01'))
# print(get_put_data('NVDA', '2026-04-01'))
print(get_put_data('^SPX', future_date))
current_price = yf.Ticker(tkr).info.get('currentPrice')
print(current_price)
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice  \
# 0    SPXW260430P02600000 2026-04-07 17:00:06+00:00  2600.0       0.20
# 1    SPXW260430P02800000 2026-04-07 15:27:07+00:00  2800.0       0.20
# 2    SPXW260430P03000000 2026-04-13 13:47:34+00:00  3000.0       0.10
# 3    SPXW260430P03200000 2026-04-08 17:50:23+00:00  3200.0       0.15
# 4    SPXW260430P03400000 2026-04-13 10:03:37+00:00  3400.0       0.20
# ..                   ...                       ...     ...        ...
# 382  SPXW260430P07990000 2026-03-06 19:46:50+00:00  7990.0    1194.55
# 383  SPXW260430P08000000 2026-04-01 17:23:50+00:00  8000.0    1371.35
# 384  SPXW260430P08100000 2026-03-23 16:12:25+00:00  8100.0    1473.58
# 385  SPXW260430P08600000 2026-04-07 14:43:37+00:00  8600.0    2018.71
# 386  SPXW260430P08800000 2026-04-02 16:51:17+00:00  8800.0    2213.76
#
#          bid      ask  change  percentChange  volume  openInterest  \
# 0       0.00     0.15    0.00       0.000000   172.0          1117
# 1       0.00     0.15    0.00       0.000000    31.0          5697
# 2       0.05     0.10   -0.10     -50.000000  2531.0           588
# 3       0.00     0.20    0.00       0.000000    35.0           274
# 4       0.05     0.20    0.09      81.818184   150.0          5187
# ..       ...      ...     ...            ...     ...           ...
# 382  1380.10  1404.10    0.00       0.000000     2.0             0
# 383  1166.70  1186.20    0.00       0.000000    39.0            54
# 384  1261.90  1280.70    0.00       0.000000     NaN             1
# 385  1765.00  1782.10    0.00       0.000000     1.0             2
# 386  1963.50  1981.80    0.00       0.000000     1.0            18
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             1.250004       False      REGULAR      USD
# 1             1.156254       False      REGULAR      USD
# 2             1.070317       False      REGULAR      USD
# 3             1.009771       False      REGULAR      USD
# 4             0.947266       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 382           0.979756        True      REGULAR      USD
# 383           0.284126        True      REGULAR      USD
# 384           0.000010        True      REGULAR      USD
# 385           0.000010        True      REGULAR      USD
# 386           0.000010        True      REGULAR      USD
#
# [387 rows x 14 columns]
# None

# %%
import yfinance as yf
import pandas as pd
import scipy

# %%
stocks = {
    "Apple" : "AAPL",
    "Microsoft" : "MSFT",
    "Nvidia" : "NVDA",
    "Palantir" : "PLTR",
    "Google" : "GOOG"
}

# %%
tkr = "NVDA"
stock_data = yf.Ticker(tkr)
print(stock_data.option_chain(stock_data.options[0])._fields)
# fields of option - calls, puts, underlying
# Out:
# ('calls', 'puts', 'underlying')

# %%
# properties of puts and calls
props = ['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
       'change', 'percentChange', 'volume', 'openInterest',
       'impliedVolatility', 'inTheMoney', 'contractSize', 'currency']

print(stock_data.option_chain(stock_data.options[0]).calls.columns)

print(stock_data.option_chain(stock_data.options[0]).puts.columns)

underlying_props = list(stock_data.option_chain(stock_data.options[0]).underlying.keys())

# print underlying properties
for i in range(len(underlying_props)):
    print(f"{underlying_props[i]}", end = ", ")
    if i > 0 and i % 5 == 0:
       print()
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency'],
#       dtype='str')
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency'],
#       dtype='str')
# language, region, quoteType, typeDisp, quoteSourceName, triggerable,
# customPriceAlertConfidence, currency, corporateActions, postMarketTime, regularMarketTime,
# exchange, messageBoardId, exchangeTimezoneName, exchangeTimezoneShortName, gmtOffSetMilliseconds,
# market, esgPopulated, marketState, regularMarketChangePercent, regularMarketPrice,
# shortName, longName, fiftyTwoWeekLowChange, fiftyTwoWeekLowChangePercent, fiftyTwoWeekRange,
# fiftyTwoWeekHighChange, fiftyTwoWeekHighChangePercent, fiftyTwoWeekLow, fiftyTwoWeekHigh, fiftyTwoWeekChangePercent,
# dividendDate, earningsTimestamp, earningsTimestampStart, earningsTimestampEnd, earningsCallTimestampStart,
# earningsCallTimestampEnd, isEarningsDateEstimate, trailingAnnualDividendRate, trailingPE, dividendRate,
# trailingAnnualDividendYield, dividendYield, epsTrailingTwelveMonths, epsForward, epsCurrentYear,
# priceEpsCurrentYear, sharesOutstanding, bookValue, fiftyDayAverage, fiftyDayAverageChange,
# fiftyDayAverageChangePercent, twoHundredDayAverage, twoHundredDayAverageChange, twoHundredDayAverageChangePercent, marketCap,
# forwardPE, priceToBook, sourceInterval, exchangeDataDelayedBy, prevName,
# nameChangeDate, averageAnalystRating, tradeable, cryptoTradeable, hasPrePostMarketData,
# firstTradeDateMilliseconds, priceHint, postMarketChangePercent, postMarketPrice, postMarketChange,
# regularMarketChange, regularMarketDayHigh, regularMarketDayRange, regularMarketDayLow, regularMarketVolume,
# regularMarketPreviousClose, bid, ask, bidSize, askSize,
# fullExchangeName, financialCurrency, regularMarketOpen, averageDailyVolume3Month, averageDailyVolume10Day,
# displayName, symbol,

# %%
exp_dat_map = dict()

i = 0
for exp in stock_data.options: # this consists of a tuple of dates that is only iterable
    exp_dat_map[exp] = i
    i += 1

exp_arg = exp_dat_map['2026-03-27']

print(stock_data.option_chain(stock_data.options[exp_arg]).calls)
print(stock_data.option_chain(stock_data.options[exp_arg]).puts)
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   NVDA260327C00050000 2026-03-27 16:34:16+00:00    50.0     118.79  115.60
# 1   NVDA260327C00055000 2026-03-27 19:13:07+00:00    55.0     112.47  110.35
# 2   NVDA260327C00060000 2026-03-27 17:30:31+00:00    60.0     108.06  105.00
# 3   NVDA260327C00065000 2026-03-27 18:55:58+00:00    65.0     102.58   99.85
# 4   NVDA260327C00070000 2026-03-27 19:21:52+00:00    70.0      97.60   94.85
# ..                  ...                       ...     ...        ...     ...
# 63  NVDA260327C00310000 2026-03-02 19:30:16+00:00   310.0       0.01    0.00
# 64  NVDA260327C00320000 2026-03-02 16:35:22+00:00   320.0       0.01    0.00
# 65  NVDA260327C00330000 2026-02-27 18:34:50+00:00   330.0       0.01    0.00
# 66  NVDA260327C00340000 2026-03-26 19:29:40+00:00   340.0       0.01    0.00
# 67  NVDA260327C00350000 2026-03-26 19:29:40+00:00   350.0       0.01    0.00
#
#        ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0   120.10 -2.790001      -2.294786      12            50          11.000003
# 1   115.25 -4.129997      -3.542022      21            37           9.937504
# 2   109.30 -4.050003      -3.612526      18            83          12.841799
# 3   105.15 -4.500000      -4.202465      18            67          13.105471
# 4   100.70 -4.599998      -4.500977      24            53           7.804688
# ..     ...       ...            ...     ...           ...                ...
# 63    0.01  0.000000       0.000000      18            77           3.500001
# 64    0.01  0.000000       0.000000       1            11           3.750001
# 65    0.01  0.000000       0.000000       1             3           3.875000
# 66    0.01  0.000000       0.000000       2            19           4.000005
# 67    0.01  0.000000       0.000000       5           941           4.125005
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# ..         ...          ...      ...
# 63       False      REGULAR      USD
# 64       False      REGULAR      USD
# 65       False      REGULAR      USD
# 66       False      REGULAR      USD
# 67       False      REGULAR      USD
#
# [68 rows x 14 columns]
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   NVDA260327P00050000 2026-03-26 14:29:24+00:00    50.0       0.01    0.00
# 1   NVDA260327P00055000 2026-03-13 14:43:21+00:00    55.0       0.01    0.00
# 2   NVDA260327P00060000 2026-03-13 19:40:16+00:00    60.0       0.01    0.00
# 3   NVDA260327P00065000 2026-03-23 16:47:57+00:00    65.0       0.01    0.00
# 4   NVDA260327P00070000 2026-03-13 19:34:14+00:00    70.0       0.01    0.00
# 5   NVDA260327P00075000 2026-03-16 15:06:15+00:00    75.0       0.01    0.00
# 6   NVDA260327P00080000 2026-03-27 15:18:23+00:00    80.0       0.01    0.00
# 7   NVDA260327P00085000 2026-03-20 19:59:35+00:00    85.0       0.01    0.00
# 8   NVDA260327P00090000 2026-03-27 13:30:02+00:00    90.0       0.02    0.00
# 9   NVDA260327P00095000 2026-03-26 14:50:15+00:00    95.0       0.01    0.00
# 10  NVDA260327P00100000 2026-03-27 19:30:29+00:00   100.0       0.01    0.00
# 11  NVDA260327P00105000 2026-03-26 17:57:51+00:00   105.0       0.01    0.00
# 12  NVDA260327P00110000 2026-03-24 17:15:50+00:00   110.0       0.01    0.00
# 13  NVDA260327P00115000 2026-03-27 19:07:50+00:00   115.0       0.01    0.00
# 14  NVDA260327P00120000 2026-03-27 13:58:42+00:00   120.0       0.01    0.00
# 15  NVDA260327P00125000 2026-03-27 19:34:44+00:00   125.0       0.01    0.00
# 16  NVDA260327P00130000 2026-03-27 18:24:02+00:00   130.0       0.01    0.00
# 17  NVDA260327P00135000 2026-03-27 19:16:02+00:00   135.0       0.01    0.00
# 18  NVDA260327P00140000 2026-03-27 19:16:14+00:00   140.0       0.01    0.00
# 19  NVDA260327P00145000 2026-03-27 19:52:46+00:00   145.0       0.01    0.00
# 20  NVDA260327P00150000 2026-03-27 19:36:24+00:00   150.0       0.01    0.00
# 21  NVDA260327P00155000 2026-03-27 19:56:21+00:00   155.0       0.01    0.00
# 22  NVDA260327P00157500 2026-03-27 19:49:43+00:00   157.5       0.01    0.00
# 23  NVDA260327P00160000 2026-03-27 19:57:44+00:00   160.0       0.01    0.00
# 24  NVDA260327P00162500 2026-03-27 19:58:03+00:00   162.5       0.01    0.00
# 25  NVDA260327P00165000 2026-03-27 19:59:59+00:00   165.0       0.01    0.01
# 26  NVDA260327P00167500 2026-03-27 19:59:59+00:00   167.5       0.17    0.14
# 27  NVDA260327P00170000 2026-03-27 19:59:49+00:00   170.0       2.34    2.51
# 28  NVDA260327P00172500 2026-03-27 19:59:32+00:00   172.5       4.89    5.00
# 29  NVDA260327P00175000 2026-03-27 19:59:41+00:00   175.0       7.41    7.50
# 30  NVDA260327P00177500 2026-03-27 19:58:07+00:00   177.5       9.92   10.00
# 31  NVDA260327P00180000 2026-03-27 19:58:02+00:00   180.0      12.49   12.50
# 32  NVDA260327P00182500 2026-03-27 19:30:40+00:00   182.5      14.99   15.00
# 33  NVDA260327P00185000 2026-03-27 19:49:01+00:00   185.0      17.63   17.35
# 34  NVDA260327P00187500 2026-03-27 19:44:21+00:00   187.5      19.77   18.80
# 35  NVDA260327P00190000 2026-03-27 19:36:22+00:00   190.0      22.70   21.35
# 36  NVDA260327P00192500 2026-03-27 15:36:27+00:00   192.5      22.74   23.75
# 37  NVDA260327P00195000 2026-03-27 14:24:22+00:00   195.0      26.69   26.30
# 38  NVDA260327P00197500 2026-03-19 17:09:18+00:00   197.5      19.75   28.75
# 39  NVDA260327P00200000 2026-03-27 17:47:14+00:00   200.0      32.12   31.35
# 40  NVDA260327P00202500 2026-03-27 17:17:45+00:00   202.5      34.00   33.60
# 41  NVDA260327P00205000 2026-03-27 15:12:25+00:00   205.0      36.24   36.35
# 42  NVDA260327P00207500 2026-03-18 19:51:32+00:00   207.5      27.00   38.75
# 43  NVDA260327P00210000 2026-03-26 19:58:40+00:00   210.0      39.79   41.30
# 44  NVDA260327P00215000 2026-03-26 17:45:36+00:00   215.0      42.32   46.30
# 45  NVDA260327P00220000 2026-03-23 14:36:26+00:00   220.0      51.45   51.30
# 46  NVDA260327P00225000 2026-03-25 14:46:27+00:00   225.0      44.39   56.30
# 47  NVDA260327P00230000 2026-03-27 13:40:41+00:00   230.0      59.11   61.30
# 48  NVDA260327P00235000 2026-03-23 19:52:30+00:00   235.0      59.98   66.30
# 49  NVDA260327P00240000 2026-03-10 13:50:24+00:00   240.0      55.20   71.30
# 50  NVDA260327P00245000 2026-03-02 14:31:22+00:00   245.0      67.35   76.30
# 51  NVDA260327P00250000 2026-02-26 15:01:27+00:00   250.0      61.50   81.30
# 52  NVDA260327P00340000 2026-02-26 20:51:59+00:00   340.0     156.30  171.30
# 53  NVDA260327P00350000 2026-02-26 20:51:59+00:00   350.0     166.28  181.30
#
#        ask     change  percentChange    volume  openInterest  \
# 0     0.01   0.000000       0.000000       1.0          2368
# 1     0.01   0.000000       0.000000     279.0          3807
# 2     0.01   0.000000       0.000000    1164.0          1040
# 3     0.01   0.000000       0.000000       5.0          2316
# 4     0.01   0.000000       0.000000       4.0           248
# 5     0.01   0.000000       0.000000       3.0           487
# 6     0.01   0.000000       0.000000      40.0           394
# 7     0.01   0.000000       0.000000    8351.0          8984
# 8     0.01   0.010000     100.000000       5.0         16396
# 9     0.01   0.000000       0.000000     112.0         11351
# 10    0.01   0.000000       0.000000      27.0         33969
# 11    0.01   0.000000       0.000000       1.0          1883
# 12    0.01   0.000000       0.000000      72.0          2828
# 13    0.01   0.000000       0.000000       8.0          1634
# 14    0.01   0.000000       0.000000       2.0          5092
# 15    0.01   0.000000       0.000000      43.0          2886
# 16    0.01   0.000000       0.000000      75.0          4374
# 17    0.01   0.000000       0.000000      93.0         10255
# 18    0.01   0.000000       0.000000     235.0         11034
# 19    0.01   0.000000       0.000000    5463.0         13796
# 20    0.01   0.000000       0.000000     447.0         53135
# 21    0.01   0.000000       0.000000    5258.0         27293
# 22    0.01  -0.010000     -50.000000    3725.0         17089
# 23    0.01  -0.020000     -66.666670   24087.0         26296
# 24    0.01  -0.040000     -80.000010   34437.0         22251
# 25    0.02  -0.170000     -94.444440  138534.0         50701
# 26    0.18  -0.300000     -63.829790  299545.0         47496
# 27    2.62   1.260000     116.666650  177679.0         52241
# 28    5.15   2.680000     121.266950   25255.0         18262
# 29    7.60   3.410000      85.250000   14627.0         35086
# 30   10.10   3.520000      55.000000    4263.0         11435
# 31   12.60   3.780000      43.398388    3828.0         10029
# 32   15.10   3.719999      33.007980      97.0            78
# 33   17.75   3.979999      29.157505      79.0            65
# 34   20.15   3.700001      23.024273       4.0            22
# 35   23.10   4.620001      25.553102      96.0           219
# 36   25.95   1.690001       8.028506       1.0            35
# 37   28.40   3.470001      14.944019       6.0            10
# 38   30.95   0.000000       0.000000     164.0             0
# 39   33.35   6.070000      23.301344       9.0             1
# 40   35.80  13.780001      68.150350       4.0             0
# 41   38.35   3.490002      10.656494       2.0             1
# 42   40.95   0.000000       0.000000       NaN             0
# 43   43.40   1.150001       2.976194      76.0            76
# 44   48.40   0.000000       0.000000       1.0             1
# 45   53.35   9.209999      21.803974      20.0             0
# 46   58.40   0.000000       0.000000       2.0             0
# 47   63.40   0.660000       1.129170      50.0            50
# 48   68.45   0.000000       0.000000       3.0             0
# 49   73.40   0.000000       0.000000       1.0             0
# 50   78.40   0.000000       0.000000       NaN             0
# 51   83.40   0.000000       0.000000       2.0             0
# 52  173.40   0.000000       0.000000       NaN             0
# 53  183.45   0.000000       0.000000       NaN             0
#
#     impliedVolatility  inTheMoney contractSize currency
# 0            7.000001       False      REGULAR      USD
# 1            6.500002       False      REGULAR      USD
# 2            6.000002       False      REGULAR      USD
# 3            5.625003       False      REGULAR      USD
# 4            5.250003       False      REGULAR      USD
# 5            4.750004       False      REGULAR      USD
# 6            4.375005       False      REGULAR      USD
# 7            4.125005       False      REGULAR      USD
# 8            3.750001       False      REGULAR      USD
# 9            3.437501       False      REGULAR      USD
# 10           3.125002       False      REGULAR      USD
# 11           2.875003       False      REGULAR      USD
# 12           2.625003       False      REGULAR      USD
# 13           2.312504       False      REGULAR      USD
# 14           2.062505       False      REGULAR      USD
# 15           1.875001       False      REGULAR      USD
# 16           1.625002       False      REGULAR      USD
# 17           1.375003       False      REGULAR      USD
# 18           1.187504       False      REGULAR      USD
# 19           0.968750       False      REGULAR      USD
# 20           0.750003       False      REGULAR      USD
# 21           0.546880       False      REGULAR      USD
# 22           0.484380       False      REGULAR      USD
# 23           0.375006       False      REGULAR      USD
# 24           0.257820       False      REGULAR      USD
# 25           0.160165       False      REGULAR      USD
# 26           0.054209       False      REGULAR      USD
# 27           0.247078        True      REGULAR      USD
# 28           0.427740        True      REGULAR      USD
# 29           0.533208        True      REGULAR      USD
# 30           0.601566        True      REGULAR      USD
# 31           0.718753        True      REGULAR      USD
# 32           0.832033        True      REGULAR      USD
# 33           0.941407        True      REGULAR      USD
# 34           1.210941        True      REGULAR      USD
# 35           1.741212        True      REGULAR      USD
# 36           2.101567        True      REGULAR      USD
# 37           2.207036        True      REGULAR      USD
# 38           2.371098        True      REGULAR      USD
# 39           2.433598        True      REGULAR      USD
# 40           2.521488        True      REGULAR      USD
# 41           2.678714        True      REGULAR      USD
# 42           2.869143        True      REGULAR      USD
# 43           2.950198        True      REGULAR      USD
# 44           3.175783        True      REGULAR      USD
# 45           3.351564        True      REGULAR      USD
# 46           3.601563        True      REGULAR      USD
# 47           3.802735        True      REGULAR      USD
# 48           4.041021        True      REGULAR      USD
# 49           4.183599        True      REGULAR      USD
# 50           4.365239        True      REGULAR      USD
# 51           4.541020        True      REGULAR      USD
# 52           7.054689        True      REGULAR      USD
# 53           7.343751        True      REGULAR      USD

# %%
# ex tkr: 'NVDA'
# ex date: '2026-03-26' (YYYY-MM-DD)
def get_call_data(tkr, date):
    stock_data = yf.Ticker(tkr)
    return stock_data.option_chain(stock_data.options[exp_dat_map[date]]).calls

def get_put_data(tkr, date):
    stock_data = yf.Ticker(tkr)
    return stock_data.option_chain(stock_data.options[exp_dat_map[date]]).puts

print(get_call_data('NVDA', '2026-04-01'))
print(get_put_data('NVDA', '2026-04-01'))
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   NVDA260401C00120000 2026-03-18 16:14:26+00:00   120.0      62.38  44.85
# 1   NVDA260401C00130000 2026-03-25 16:40:08+00:00   130.0      49.20  34.95
# 2   NVDA260401C00135000 2026-03-25 13:44:52+00:00   135.0      44.30  31.75
# 3   NVDA260401C00140000 2026-03-27 19:35:05+00:00   140.0      27.43  26.90
# 4   NVDA260401C00145000 2026-03-27 18:45:15+00:00   145.0      23.15  21.95
# 5   NVDA260401C00150000 2026-03-27 17:53:29+00:00   150.0      18.08  17.05
# 6   NVDA260401C00155000 2026-03-27 19:59:53+00:00   155.0      12.95  12.15
# 7   NVDA260401C00160000 2026-03-27 19:50:08+00:00   160.0       8.40   8.20
# 8   NVDA260401C00165000 2026-03-27 19:59:13+00:00   165.0       4.65   4.45
# 9   NVDA260401C00170000 2026-03-27 19:59:59+00:00   170.0       1.89   1.88
# 10  NVDA260401C00175000 2026-03-27 19:59:59+00:00   175.0       0.62   0.61
# 11  NVDA260401C00180000 2026-03-27 19:59:24+00:00   180.0       0.20   0.19
# 12  NVDA260401C00185000 2026-03-27 19:59:41+00:00   185.0       0.08   0.07
# 13  NVDA260401C00190000 2026-03-27 19:46:18+00:00   190.0       0.04   0.03
# 14  NVDA260401C00195000 2026-03-27 19:46:10+00:00   195.0       0.01   0.01
# 15  NVDA260401C00200000 2026-03-27 19:45:02+00:00   200.0       0.01   0.00
# 16  NVDA260401C00205000 2026-03-26 19:50:54+00:00   205.0       0.02   0.00
# 17  NVDA260401C00210000 2026-03-27 18:41:21+00:00   210.0       0.01   0.00
# 18  NVDA260401C00215000 2026-03-26 19:36:40+00:00   215.0       0.01   0.00
# 19  NVDA260401C00220000 2026-03-25 15:19:16+00:00   220.0       0.01   0.00
# 20  NVDA260401C00230000 2026-03-25 13:37:26+00:00   230.0       0.01   0.00
# 21  NVDA260401C00235000 2026-03-23 19:24:04+00:00   235.0       0.01   0.00
# 22  NVDA260401C00240000 2026-03-18 16:56:18+00:00   240.0       0.02   0.00
# 23  NVDA260401C00250000 2026-03-17 18:46:37+00:00   250.0       0.01   0.00
# 24  NVDA260401C00255000 2026-03-17 18:22:49+00:00   255.0       0.02   0.00
#
#       ask  change  percentChange   volume  openInterest  impliedVolatility  \
# 0   50.85    0.00       0.000000      NaN            30           1.414065
# 1   40.85    0.00       0.000000      3.0             4           1.150395
# 2   33.55    0.00       0.000000     81.0            42           0.833986
# 3   28.40   -4.57     -14.281249     46.0            53           0.711917
# 4   23.45   -8.75     -27.429468      1.0             3           0.626957
# 5   18.50  -10.58     -36.915560      3.0            19           0.539067
# 6   13.70  -11.03     -45.996666     55.0            28           0.632816
# 7    8.35   -3.81     -31.203934    214.0           282           0.396490
# 8    4.55   -3.15     -40.384613    594.0           346           0.368170
# 9    1.92   -2.46     -56.551723   8418.0          4193           0.347419
# 10   0.63   -1.32     -68.041240   9979.0          2144           0.342048
# 11   0.20   -0.51     -71.830986  13043.0          5920           0.357428
# 12   0.09   -0.17     -68.000000   3091.0          8816           0.399420
# 13   0.05   -0.06     -60.000000    901.0          3667           0.447271
# 14   0.02   -0.04     -80.000010    558.0          2517           0.468755
# 15   0.01   -0.02     -66.666670    507.0          1666           0.500005
# 16   0.01    0.00       0.000000     15.0           618           0.531255
# 17   0.01    0.00       0.000000     23.0           505           0.578129
# 18   0.01    0.00       0.000000      1.0           178           0.640629
# 19   0.01    0.00       0.000000      4.0            11           0.687503
# 20   0.01    0.00       0.000000      1.0            29           0.781252
# 21   0.01    0.00       0.000000     10.0            14           0.843752
# 22   0.01    0.00       0.000000      NaN             6           0.875001
# 23   0.01    0.00       0.000000      NaN             5           0.968750
# 24   0.01    0.00       0.000000      NaN             3           1.031255
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   NVDA260401P00110000 2026-03-27 19:09:07+00:00   110.0       0.02   0.01
# 1   NVDA260401P00120000 2026-03-27 19:46:30+00:00   120.0       0.03   0.02
# 2   NVDA260401P00125000 2026-03-27 19:30:56+00:00   125.0       0.04   0.02
# 3   NVDA260401P00130000 2026-03-27 19:49:48+00:00   130.0       0.05   0.03
# 4   NVDA260401P00135000 2026-03-27 19:20:02+00:00   135.0       0.06   0.05
# 5   NVDA260401P00140000 2026-03-27 19:44:16+00:00   140.0       0.10   0.07
# 6   NVDA260401P00145000 2026-03-27 19:59:34+00:00   145.0       0.10   0.10
# 7   NVDA260401P00150000 2026-03-27 19:57:22+00:00   150.0       0.16   0.15
# 8   NVDA260401P00155000 2026-03-27 19:57:18+00:00   155.0       0.28   0.30
# 9   NVDA260401P00160000 2026-03-27 19:59:54+00:00   160.0       0.75   0.76
# 10  NVDA260401P00165000 2026-03-27 19:59:51+00:00   165.0       1.91   1.97
# 11  NVDA260401P00170000 2026-03-27 19:59:15+00:00   170.0       4.25   4.35
# 12  NVDA260401P00175000 2026-03-27 19:58:52+00:00   175.0       7.88   8.00
# 13  NVDA260401P00180000 2026-03-27 19:57:58+00:00   180.0      12.61  12.05
# 14  NVDA260401P00185000 2026-03-27 19:51:41+00:00   185.0      17.81  16.55
# 15  NVDA260401P00190000 2026-03-27 13:40:09+00:00   190.0      19.10  21.20
# 16  NVDA260401P00195000 2026-03-27 14:04:09+00:00   195.0      26.20  26.20
# 17  NVDA260401P00200000 2026-03-26 17:14:52+00:00   200.0      26.18  31.20
# 18  NVDA260401P00205000 2026-03-25 18:33:24+00:00   205.0      26.00  36.10
#
#       ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0    0.03  0.000000       0.000000      99           108           1.203129
# 1    0.04  0.020000     200.000000     199            85           1.015630
# 2    0.04  0.020000     100.000000     129           159           0.898439
# 3    0.05  0.030000     150.000000     473           190           0.820314
# 4    0.06  0.030000     100.000000     944           125           0.738284
# 5    0.09  0.050000     100.000000     860           298           0.660160
# 6    0.12  0.010000      11.111108    7399          2380           0.576176
# 7    0.17  0.020000      14.285711    1153          1062           0.497075
# 8    0.31  0.010000       3.703700    2599          1372           0.426764
# 9    0.78  0.130000      20.967741    3901          6577           0.387213
# 10   2.02  0.460000      31.724133    6289          3998           0.366950
# 11   4.45  1.290000      43.581080    3680          3988           0.353522
# 12   8.20  2.340000      42.238270    1214          6238           0.358405
# 13  12.90  3.490000      38.267540     644          1521           0.426764
# 14  18.00  5.009999      39.140620      78           211           0.570805
# 15  23.15  1.400000       7.909603       1            70           0.724612
# 16  28.15  3.200001      13.913046       2             0           0.832033
# 17  33.15  0.000000       0.000000       2             0           0.933594
# 18  38.60  0.000000       0.000000       2             0           1.163578
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
